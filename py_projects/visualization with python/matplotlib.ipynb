# %%
# import pandas as pd
import pandas as pd
	
# List1
lst = [['tom', 25], ['krish', 30],
	['nick', 26], ['juli', 22]]
	
df = pd.DataFrame(lst, columns =['Name', 'Age'])
df
# Out:
#     Name  Age
# 0    tom   25
# 1  krish   30
# 2   nick   26
# 3   juli   22

# %%
df.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
df['Age'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>
